# %% [markdown]
# <a href="https://colab.research.google.com/github/Fhanafii/Klasifikasi-DecisionTree-di-dataset-wine/blob/main/Wine_Dataset_DecisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
#import dataset dari Google Drive memakai path
path = "/content/drive/MyDrive/Dataset/wine.data"
wine_ds = pd.read_csv(path)

# %%
wine_ds = pd.read_csv(path, header=None, delimiter=',')
# Menambahkan nama kolom
column_names = ['class','Alcohol', 'Malicacid', 'Ash', 'Alcalinity_of_ash', 'Magnesium','Total_phenols','Flavanoids','Nonflavanoid_phenols','Proanthocyanins','Color_intensity','Hue','0D280_0D315_of_diluted_wines','Proline']  # Modify according to your dataset
wine_ds = pd.read_csv(path, names=column_names)
# Menampilkan Data
wine_ds
# Out:
#      class  Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  \
# 0        1    14.23       1.71  2.43               15.6        127
# 1        1    13.20       1.78  2.14               11.2        100
# 2        1    13.16       2.36  2.67               18.6        101
# 3        1    14.37       1.95  2.50               16.8        113
# 4        1    13.24       2.59  2.87               21.0        118
# ..     ...      ...        ...   ...                ...        ...
# 173      3    13.71       5.65  2.45               20.5         95
# 174      3    13.40       3.91  2.48               23.0        102
# 175      3    13.27       4.28  2.26               20.0        120
# 176      3    13.17       2.59  2.37               20.0        120
# 177      3    14.13       4.10  2.74               24.5         96
#
#      Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
# Mendeklarasikan variable x dan y
X = wine_ds.drop('class', axis=1)
y = wine_ds['class']

# %%
#memisahkan data x dan y
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (142, 13) (36, 13) (142,) (36,)

# %%
# Inisialisasi model Decision Tree
model = DecisionTreeClassifier(criterion='entropy')
# Melatih model
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
#prediksi pada data
y_pred = model.predict(X_test)

# %%
#membuat confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[10  1  0]
#  [ 2 12  0]
#  [ 0  0 11]]

# %%
#mengukur akurasi model
accuracy = accuracy_score(y_pred, y_test)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.9166666666666666

# %%
# Fit a Decision Tree model
model = DecisionTreeClassifier()
model.fit(X, y)

# Plot the Decision Tree
fig = plt.figure(figsize=(20, 10))
class_names_string = [str(class_name) for class_name in y.unique()]
plot_tree(model, feature_names=column_names[:-1], class_names=class_names_string, filled=True)
plt.show()
